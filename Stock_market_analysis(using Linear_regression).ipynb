# %%
import pandas as pd
df=pd.read_csv("D:\\miniproject\\stocks.csv")
df
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# 3    151.009995  57450700
# 4    153.850006  62199000
# ..          ...       ...
# 243  107.709999  20926300
# 244  105.980003  20343100
# 245  106.120003  17116300
# 246  105.209999  19780600
# 247  106.214996  20705300
#
# [248 rows x 8 columns]

# %%
df.head()
# Out:
#   Ticker        Date        Open        High         Low       Close  \
# 0   AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1   AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2   AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3   AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4   AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
#
#     Adj Close    Volume
# 0  154.414230  83322600
# 1  151.688400  64120100
# 2  150.639999  56007100
# 3  151.009995  57450700
# 4  153.850006  62199000

# %%
df.shape
# Out:
# (248, 8)

# %%
df.drop(['Ticker','Adj Close'],axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close    Volume
# 0  2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1  2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2  2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3  2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4  2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    248 non-null    object
#  1   Open    248 non-null    float64
#  2   High    248 non-null    float64
#  3   Low     248 non-null    float64
#  4   Close   248 non-null    float64
#  5   Volume  248 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  248.000000  248.000000  248.000000  248.000000  2.480000e+02
# mean   215.252093  217.919662  212.697452  215.381674  3.208210e+07
# std     91.691315   92.863023   90.147881   91.461989  2.233590e+07
# min     89.540001   90.129997   88.860001   89.349998  2.657900e+06
# 25%    135.235004  137.440004  134.822495  136.347498  1.714180e+07
# 50%    208.764999  212.614998  208.184998  209.920006  2.734000e+07
# 75%    304.177505  307.565002  295.437500  303.942505  4.771772e+07
# max    372.410004  373.829987  361.739990  366.829987  1.133164e+08

# %%
print('lenghth of dataset:',len(df))
# Out:
# lenghth of dataset: 248

# %%
import matplotlib.pyplot as plt
df['Open'].plot(figsize=(16,6))
plt.title('Linechart')
plt.xlabel('Open')
plt.ylabel('frequency')
plt.show()

# %%
x=df.drop(['Close','Date'],axis=1)
x
# Out:
#            Open        High         Low    Volume
# 0    150.639999  155.229996  150.639999  83322600
# 1    153.880005  154.580002  151.169998  64120100
# 2    153.779999  154.330002  150.419998  56007100
# 3    149.460007  151.339996  149.220001  57450700
# 4    150.949997  154.259995  150.919998  62199000
# ..          ...         ...         ...       ...
# 243  107.720001  108.680000  107.500000  20926300
# 244  107.660004  107.730003  104.500000  20343100
# 245  106.220001  108.129997  105.620003  17116300
# 246  106.160004  106.300003  104.699997  19780600
# 247  105.320000  106.440002  104.738998  20705300
#
# [248 rows x 4 columns]

# %%
y=df['Close']
y
# Out:
# 0      154.649994
# 1      151.919998
# 2      150.869995
# 3      151.009995
# 4      153.850006
#           ...
# 243    107.709999
# 244    105.980003
# 245    106.120003
# 246    105.209999
# 247    106.214996
# Name: Close, Length: 248, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=100)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (173, 4)
# (75, 4)
# (173,)
# (75,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [-4.49699238e-01  7.20506451e-01  7.29344055e-01 -5.15571896e-09]

# %%
print(regressor.intercept_)
# Out:
# 0.19893297041403457

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([262.84534885, 168.70520536,  94.84239894, 287.97175571,
#         93.55914731, 334.61881294, 303.43732511, 342.36456049,
#        102.50533006, 321.77840517, 302.09931064, 159.8253462 ,
#        318.70813674, 365.8706861 , 104.2088792 , 319.53849613,
#        264.51980443, 253.81898698, 255.30611267,  96.3588503 ,
#        165.24410071, 105.86475207, 271.93679353, 278.00159575,
#        108.35856758,  94.05040291, 154.70820621, 339.02258569,
#         99.88275381,  95.7813866 , 265.92878703, 346.35729012,
#        150.56484657, 105.68252775, 159.10747643, 280.24137099,
#        317.99346371, 287.29097459, 107.89074321, 163.92875629,
#        306.08449101, 106.21742875,  95.42833697, 106.96112201,
#        250.60817022, 339.03472855, 151.99588118, 288.52150646,
#        266.11496995, 158.09127778, 160.85952486, 106.14467561,
#        337.43443048, 300.05288119, 166.68232365, 287.26209159,
#        151.35592475, 309.26549295, 167.50740853, 148.70778922,
#        164.63034772, 331.86918045, 359.65793439,  94.54580991,
#        148.16362892, 145.72589797, 104.80368007, 151.57192104,
#        343.93785119, 307.10135038, 105.51604416, 163.76699599,
#        255.52248445, 273.44227948, 303.39705179])

# %%
print(x_test)
# Out:
#            Open        High         Low    Volume
# 65   261.529999  264.089996  260.660004  25818500
# 59   169.500000  170.919998  167.160004  65136000
# 205   95.419998   96.089996   93.844002  24101500
# 112  285.250000  289.029999  285.079987  23244400
# 191   94.660004   95.175003   92.650002  42513100
# ..          ...         ...         ...       ...
# 244  107.660004  107.730003  104.500000  20343100
# 37   162.440002  165.000000  161.910004  68749800
# 83   255.820007  259.559998  251.580002  26653400
# 96   275.790009  276.140015  272.049988  21878600
# 153  306.320007  307.920013  300.429993   4886300
#
# [75 rows x 4 columns]

# %%
predicted.shape
# Out:
# (75,)

# %%
dframe=pd.DataFrame(y_test,predicted)
dframe
# Out:
#             Close
# 262.845349    NaN
# 168.705205    NaN
# 94.842399     NaN
# 287.971756    NaN
# 93.559147     NaN
# ...           ...
# 105.516044    NaN
# 163.766996    NaN
# 255.522484    NaN
# 273.442279    NaN
# 303.397052    NaN
#
# [75 rows x 1 columns]

# %%
dfr=pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted})
dfr
# Out:
#      Actual Price  Predicted Price
# 65     263.100006       262.845349
# 59     167.449997       168.705205
# 205     94.169998        94.842399
# 112    286.109985       287.971756
# 191     94.949997        93.559147
# ..            ...              ...
# 244    105.980003       105.516044
# 37     164.899994       163.766996
# 83     252.320007       255.522484
# 96     275.230011       273.442279
# 153    305.790009       303.397052
#
# [75 rows x 2 columns]

# %%
dfr.head(60)
# Out:
#      Actual Price  Predicted Price
# 65     263.100006       262.845349
# 59     167.449997       168.705205
# 205     94.169998        94.842399
# 112    286.109985       287.971756
# 191     94.949997        93.559147
# 168    331.029999       334.618813
# 151    303.500000       303.437325
# 161    345.480011       342.364560
# 213    102.459999       102.505330
# 184    320.779999       321.778405
# 117    304.829987       302.099311
# 31     158.929993       159.825346
# 139    313.480011       318.708137
# 126    362.500000       365.870686
# 224    104.910004       104.208879
# 173    323.119995       319.538496
# 69     262.149994       264.519804
# 85     253.919998       253.818987
# 81     254.149994       255.306113
# 192     97.099998        96.358850
# 46     165.210007       165.244101
# 230    105.220001       105.864752
# 88     276.200012       271.936794
# 115    275.420013       278.001596
# 243    107.709999       108.358568
# 207     92.660004        94.050403
# 26     155.850006       154.708206
# 164    342.350006       339.022586
# 212    101.070000        99.882754
# 204     95.580002        95.781387
# 64     263.619995       265.928787
# 163    346.750000       346.357290
# 3      151.009995       150.564847
# 225    105.120003       105.682528
# 32     160.250000       159.107476
# 97     280.510010       280.241371
# 142    312.029999       317.993464
# 111    288.450012       287.290975
# 227    108.900002       107.890743
# 41     164.660004       163.928756
# 120    305.410004       306.084491
# 216    104.220001       106.217429
# 188     95.459999        95.428337
# 242    108.220001       106.961122
# 75     250.160004       250.608170
# 160    338.429993       339.034729
# 19     151.600006       151.995881
# 101    287.179993       288.521506
# 62     267.559998       266.114970
# 29     159.279999       158.091278
# 42     162.029999       160.859525
# 237    105.910004       106.144676
# 166    338.989990       337.434430
# 145    297.779999       300.052881
# 48     166.470001       166.682324
# 99     288.299988       287.262092
# 23     150.470001       151.355925
# 123    310.649994       309.265493
# 55     168.410004       167.507409
# 22     148.500000       148.707789

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy:',train_accuracy)
L_test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy:',L_test_accuracy)
# Out:
# train_accuracy: 0.9996511868334682
# test_accuracy: 0.9995657233927607

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean Absolute Error: 1.4257164840711727
# Mean Squared Error: 3.622622314196091
# Root Mean Squared Error: 1.9033187631597843

# %%
graph=dfr.head(20)
graph
# Out:
#      Actual Price  Predicted Price
# 65     263.100006       262.845349
# 59     167.449997       168.705205
# 205     94.169998        94.842399
# 112    286.109985       287.971756
# 191     94.949997        93.559147
# 168    331.029999       334.618813
# 151    303.500000       303.437325
# 161    345.480011       342.364560
# 213    102.459999       102.505330
# 184    320.779999       321.778405
# 117    304.829987       302.099311
# 31     158.929993       159.825346
# 139    313.480011       318.708137
# 126    362.500000       365.870686
# 224    104.910004       104.208879
# 173    323.119995       319.538496
# 69     262.149994       264.519804
# 85     253.919998       253.818987
# 81     254.149994       255.306113
# 192     97.099998        96.358850

# %%
graph.plot(kind='bar')
plt.title('BarGraph')
plt.xlabel('Actual&prediceted price')
plt.ylabel('frequency')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([263.10530273, 169.23229431,  94.72049988, 287.09580902,
#         96.13319931, 337.23859558, 308.35470062, 338.05969788,
#        102.40370041, 321.44059875, 301.31510223, 158.0619014 ,
#        319.65579315, 363.52479065, 103.36759834, 320.78829468,
#        265.80080429, 252.5687001 , 255.93499954,  95.72840034,
#        164.62190094, 106.06444992, 268.15470825, 278.05780426,
#        108.58310036,  94.46259918, 154.23179977, 338.4689975 ,
#         99.19180061,  94.66269981, 268.66100861, 349.19309692,
#        149.06559753, 105.34794876, 157.95819931, 279.04799988,
#        318.63529175, 288.0167099 , 108.18700111, 163.51559692,
#        305.11129639, 105.30769897, 100.61240067, 107.94270073,
#        250.17279709, 338.102099  , 152.21599854, 288.71270142,
#        264.95800385, 157.53699692, 160.60520401, 106.23714966,
#        335.06309998, 307.41060059, 166.17129959, 288.05020294,
#        151.00169907, 307.88599945, 166.887099  , 150.37329834,
#        164.93689896, 330.62449829, 359.59399628,  96.2929995 ,
#        148.99180099, 147.02310516, 104.11209869, 152.25619659,
#        339.65099823, 305.16129761, 105.47555   , 163.82029694,
#        255.73699936, 273.4361026 , 306.13930298])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy:',train_accuracy)
R_test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy:',R_test_accuracy)
# Out:
# train_accuracy: 0.9998697656763121
# test_accuracy: 0.998964725695802

# %%
import matplotlib.pyplot as plt
linear_regression_accuracy =0.9995657233927607
random_forest_accuracy =0.9863406841303611
accuracy_scores = [linear_regression_accuracy, random_forest_accuracy]
model_names = ['Linear Regression', 'Random Forest Regression']
plt.bar(model_names, accuracy_scores)
plt.xlabel('Regression Models')
plt.ylabel('Test Accuracy')
plt.title('Comparison of Test Accuracy: Linear Regression vs Random Forest Regression')

plt.show()
