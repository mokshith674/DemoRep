# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Reading the dataset
df=pd.read_csv("D:\\miniproject\\stocks.csv")
df
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# 3    151.009995  57450700
# 4    153.850006  62199000
# ..          ...       ...
# 243  107.709999  20926300
# 244  105.980003  20343100
# 245  106.120003  17116300
# 246  105.209999  19780600
# 247  106.214996  20705300
#
# [248 rows x 8 columns]

# %%
df.drop(['Ticker','Adj Close'],axis=1,inplace=True)
df
# Out:
#            Date        Open        High         Low       Close    Volume
# 0    2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1    2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2    2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3    2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4    2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000
# ..          ...         ...         ...         ...         ...       ...
# 243  2023-05-01  107.720001  108.680000  107.500000  107.709999  20926300
# 244  2023-05-02  107.660004  107.730003  104.500000  105.980003  20343100
# 245  2023-05-03  106.220001  108.129997  105.620003  106.120003  17116300
# 246  2023-05-04  106.160004  106.300003  104.699997  105.209999  19780600
# 247  2023-05-05  105.320000  106.440002  104.738998  106.214996  20705300
#
# [248 rows x 6 columns]

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close    Volume
# 0  2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1  2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2  2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3  2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4  2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close    Volume
# 0  2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1  2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2  2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3  2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4  2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000

# %%
df.tail()
# Out:
#            Date        Open        High         Low       Close    Volume
# 243  2023-05-01  107.720001  108.680000  107.500000  107.709999  20926300
# 244  2023-05-02  107.660004  107.730003  104.500000  105.980003  20343100
# 245  2023-05-03  106.220001  108.129997  105.620003  106.120003  17116300
# 246  2023-05-04  106.160004  106.300003  104.699997  105.209999  19780600
# 247  2023-05-05  105.320000  106.440002  104.738998  106.214996  20705300

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    248 non-null    object
#  1   Open    248 non-null    float64
#  2   High    248 non-null    float64
#  3   Low     248 non-null    float64
#  4   Close   248 non-null    float64
#  5   Volume  248 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  248.000000  248.000000  248.000000  248.000000  2.480000e+02
# mean   215.252093  217.919662  212.697452  215.381674  3.208210e+07
# std     91.691315   92.863023   90.147881   91.461989  2.233590e+07
# min     89.540001   90.129997   88.860001   89.349998  2.657900e+06
# 25%    135.235004  137.440004  134.822495  136.347498  1.714180e+07
# 50%    208.764999  212.614998  208.184998  209.920006  2.734000e+07
# 75%    304.177505  307.565002  295.437500  303.942505  4.771772e+07
# max    372.410004  373.829987  361.739990  366.829987  1.133164e+08

# %%
print('lenghth of dataset:',len(df))
print('shape of the dataset',df.shape)
# Out:
# lenghth of dataset: 248
# shape of the dataset (248, 6)

# %%
print("Number of columns in the dataset:\n",df.columns)
# Out:
# Number of columns in the dataset:
#  Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
import matplotlib.pyplot as plt
df['Open'].plot(figsize=(16,6))
plt.title('Linechart')
plt.xlabel('Open')
plt.ylabel('frequency')
plt.show()

# %%
x=df
x['year']=pd.DatetimeIndex(x['Date']).year
x['month']=pd.DatetimeIndex(x['Date']).month
x['day']=pd.DatetimeIndex(x['Date']).day

# %%
x
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0    2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1    2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2    2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3    2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4    2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000
# ..          ...         ...         ...         ...         ...       ...
# 243  2023-05-01  107.720001  108.680000  107.500000  107.709999  20926300
# 244  2023-05-02  107.660004  107.730003  104.500000  105.980003  20343100
# 245  2023-05-03  106.220001  108.129997  105.620003  106.120003  17116300
# 246  2023-05-04  106.160004  106.300003  104.699997  105.209999  19780600
# 247  2023-05-05  105.320000  106.440002  104.738998  106.214996  20705300
#
#      year  month  day
# 0    2023      2    7
# 1    2023      2    8
# 2    2023      2    9
# 3    2023      2   10
# 4    2023      2   13
# ..    ...    ...  ...
# 243  2023      5    1
# 244  2023      5    2
# 245  2023      5    3
# 246  2023      5    4
# 247  2023      5    5
#
# [248 rows x 9 columns]

# %%
x=df.drop(['Close','Date'],axis=1)
x
# Out:
#            Open        High         Low    Volume  year  month  day
# 0    150.639999  155.229996  150.639999  83322600  2023      2    7
# 1    153.880005  154.580002  151.169998  64120100  2023      2    8
# 2    153.779999  154.330002  150.419998  56007100  2023      2    9
# 3    149.460007  151.339996  149.220001  57450700  2023      2   10
# 4    150.949997  154.259995  150.919998  62199000  2023      2   13
# ..          ...         ...         ...       ...   ...    ...  ...
# 243  107.720001  108.680000  107.500000  20926300  2023      5    1
# 244  107.660004  107.730003  104.500000  20343100  2023      5    2
# 245  106.220001  108.129997  105.620003  17116300  2023      5    3
# 246  106.160004  106.300003  104.699997  19780600  2023      5    4
# 247  105.320000  106.440002  104.738998  20705300  2023      5    5
#
# [248 rows x 7 columns]

# %%
y=df['Close']
y
# Out:
# 0      154.649994
# 1      151.919998
# 2      150.869995
# 3      151.009995
# 4      153.850006
#           ...
# 243    107.709999
# 244    105.980003
# 245    106.120003
# 246    105.209999
# 247    106.214996
# Name: Close, Length: 248, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)
print('xtrain:',x_train.shape)
print('xtest:',x_test.shape)
print('ytain:',y_train.shape)
print('ytest:',y_test.shape)
# Out:
# xtrain: (186, 7)
# xtest: (62, 7)
# ytain: (186,)
# ytest: (62,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('Co-efficient:',regressor.coef_)
# Out:
# Co-efficient: [-5.45434461e-01  7.34498290e-01  8.12746520e-01  4.09319930e-09
#   6.34908792e-16  1.03687704e-01  1.15818167e-03]

# %%
print('intercept:',regressor.intercept_)
# Out:
# intercept: -0.6115052912800536

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([105.85857405, 333.96873085, 250.74241162, 311.28519689,
#        298.72203511, 252.57616138, 164.91324929, 331.00275856,
#        105.25785819, 102.92673365, 273.32821516,  90.64360737,
#        255.40317671, 331.12356914, 342.36046574,  91.6712785 ,
#        168.06448415, 296.21632029, 105.89362416, 278.38275047,
#         93.67596025, 317.78324839, 346.0692463 , 280.914753  ,
#        160.98083308,  93.78619591, 164.20050281, 287.47227794,
#        270.45727295, 288.53794467, 307.59001879, 151.74176022,
#         95.67940527, 265.26741985, 359.00929825, 152.44792433,
#        148.89679411, 364.91355333, 146.15607972, 319.25252252,
#        107.63243018, 104.87900905, 288.31418623, 329.21735632,
#        250.40020544, 324.40533805, 105.06920989, 359.55324439,
#        249.39064507, 104.18635543, 285.82181447, 155.70870856,
#         94.61028593, 145.83820822, 253.07013501, 155.62258755,
#        106.45123935, 328.76510696, 291.59428566, 338.8283384 ,
#        101.96923654, 365.08969585])

# %%
print(x_test)
# Out:
#            Open        High         Low    Volume  year  month  day
# 247  105.320000  106.440002  104.738998  20705300  2023      5    5
# 168  340.809998  342.799988  330.040009   3965400  2023      4   12
# 76   249.070007  251.490005  248.729996  22491000  2023      2   28
# 150  304.750000  316.600006  301.709991   7903700  2023      3   16
# 145  312.079987  312.510010  294.880005   7443400  2023      3    9
# ..          ...         ...         ...       ...   ...    ...  ...
# 180  325.239990  330.809998  324.000000   4221900  2023      4   28
# 146  297.899994  298.790009  289.000000   5759300  2023      3   10
# 160  340.269989  343.290009  335.299988   7131500  2023      3   30
# 214  101.059998  102.580002  100.790001  26033900  2023      3   20
# 126  372.410004  373.829987  361.739990   6901100  2023      2    9
#
# [62 rows x 7 columns]

# %%
predicted.shape
# Out:
# (62,)

# %%
dframe=pd.DataFrame(y_test,predicted)
dframe
# Out:
#             Close
# 105.858574    NaN
# 333.968731    NaN
# 250.742412    NaN
# 311.285197    NaN
# 298.722035    NaN
# ...           ...
# 328.765107    NaN
# 291.594286    NaN
# 338.828338    NaN
# 101.969237    NaN
# 365.089696    NaN
#
# [62 rows x 1 columns]

# %%
dfr=pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted,'Diffrence':y_test-predicted})
dfr
# Out:
#      Actual Price  Predicted Price  Diffrence
# 247    106.214996       105.858574   0.356422
# 168    331.029999       333.968731  -2.938732
# 76     249.419998       250.742412  -1.322413
# 150    310.059998       311.285197  -1.225199
# 145    297.779999       298.722035  -0.942036
# ..            ...              ...        ...
# 180    329.929993       328.765107   1.164886
# 146    292.760010       291.594286   1.165724
# 160    338.429993       338.828338  -0.398346
# 214    101.930000       101.969237  -0.039236
# 126    362.500000       365.089696  -2.589696
#
# [62 rows x 3 columns]

# %%
dfr.head(60)
# Out:
#      Actual Price  Predicted Price  Diffrence
# 247    106.214996       105.858574   0.356422
# 168    331.029999       333.968731  -2.938732
# 76     249.419998       250.742412  -1.322413
# 150    310.059998       311.285197  -1.225199
# 145    297.779999       298.722035  -0.942036
# 73     254.770004       252.576161   2.193843
# 45     165.559998       164.913249   0.646748
# 159    332.029999       331.002759   1.027240
# 218    106.059998       105.257858   0.802139
# 213    102.459999       102.926734  -0.466735
# 96     275.230011       273.328215   1.901796
# 201     90.510002        90.643607  -0.133605
# 83     252.320007       255.403177  -3.083169
# 176    329.019989       331.123569  -2.103580
# 161    345.480011       342.360466   3.119545
# 202     92.309998        91.671279   0.638719
# 55     168.410004       168.064484   0.345520
# 116    295.369995       296.216320  -0.846325
# 229    106.120003       105.893624   0.226379
# 92     272.290009       278.382750  -6.092742
# 203     94.019997        93.675960   0.344036
# 135    323.649994       317.783248   5.866746
# 162    348.279999       346.069246   2.210752
# 89     279.429993       280.914753  -1.484760
# 44     160.100006       160.980833  -0.880827
# 207     92.660004        93.786196  -1.126192
# 37     164.899994       164.200503   0.699491
# 111    288.450012       287.472278   0.977734
# 63     266.730011       270.457273  -3.727262
# 109    288.799988       288.537945   0.262043
# 118    307.260010       307.590019  -0.330009
# 8      152.550003       151.741760   0.808243
# 189     94.860001        95.679405  -0.819405
# 64     263.619995       265.267420  -1.647425
# 129    359.959991       359.009298   0.950693
# 5      153.199997       152.447924   0.752073
# 22     148.500000       148.896794  -0.396794
# 125    366.829987       364.913553   1.916433
# 12     146.710007       146.156080   0.553927
# 173    323.119995       319.252523   3.867473
# 241    108.370003       107.632430   0.737573
# 226    104.949997       104.879009   0.070988
# 107    289.839996       288.314186   1.525810
# 156    328.390015       329.217356  -0.827342
# 75     250.160004       250.400205  -0.240202
# 178    321.149994       324.405338  -3.255344
# 235    105.019997       105.069210  -0.049213
# 130    361.420013       359.553244   1.866769
# 74     249.220001       249.390645  -0.170644
# 224    104.910004       104.186355   0.723648
# 108    286.140015       285.821814   0.318200
# 18     153.830002       155.708709  -1.878707
# 205     94.169998        94.610286  -0.440288
# 15     145.309998       145.838208  -0.528211
# 71     252.669998       253.070135  -0.400137
# 7      153.710007       155.622588  -1.912581
# 228    106.949997       106.451239   0.498758
# 180    329.929993       328.765107   1.164886
# 146    292.760010       291.594286   1.165724
# 160    338.429993       338.828338  -0.398346

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy(R_Squared):',train_accuracy)
test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy(R_Squared):',test_accuracy)
# Out:
# train_accuracy(R_Squared): 0.9996274457101879
# test_accuracy(R_Squared): 0.9996351890659423

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean Absolute Error: 1.3038307748950013
# Mean Squared Error: 3.3155240230458447
# Root Mean Squared Error: 1.8208580458250567

# %%
graph=dfr.head(20)
graph
# Out:
#      Actual Price  Predicted Price  Diffrence
# 247    106.214996       105.858574   0.356422
# 168    331.029999       333.968731  -2.938732
# 76     249.419998       250.742412  -1.322413
# 150    310.059998       311.285197  -1.225199
# 145    297.779999       298.722035  -0.942036
# 73     254.770004       252.576161   2.193843
# 45     165.559998       164.913249   0.646748
# 159    332.029999       331.002759   1.027240
# 218    106.059998       105.257858   0.802139
# 213    102.459999       102.926734  -0.466735
# 96     275.230011       273.328215   1.901796
# 201     90.510002        90.643607  -0.133605
# 83     252.320007       255.403177  -3.083169
# 176    329.019989       331.123569  -2.103580
# 161    345.480011       342.360466   3.119545
# 202     92.309998        91.671279   0.638719
# 55     168.410004       168.064484   0.345520
# 116    295.369995       296.216320  -0.846325
# 229    106.120003       105.893624   0.226379
# 92     272.290009       278.382750  -6.092742

# %%
graph.plot(kind='bar')
plt.title('BarGraph')
plt.xlabel('Actual&prediceted price')
plt.ylabel('frequency')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (186, 7)
# (62, 7)
# (186,)
# (62,)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([105.38760078, 337.45789642, 250.62739746, 313.11259766,
#        307.69590118, 253.78079651, 162.87259964, 325.50059723,
#        104.99010033, 101.03740013, 276.95290436,  90.88290092,
#        255.54429672, 327.82380035, 338.49260162,  91.16810143,
#        166.5769014 , 296.16890137, 106.14870079, 275.92110474,
#         93.342201  , 321.05279755, 346.09240021, 277.50380615,
#        161.46710129,  94.48790001, 163.51239929, 287.15849487,
#        274.16121063, 289.71600037, 304.84379944, 152.79560074,
#         96.0186998 , 271.86460754, 355.74520111, 152.96110031,
#        150.43349762, 358.33940521, 148.09220169, 320.20699524,
#        108.38180038, 105.46430092, 287.94010162, 325.42760345,
#        251.0708963 , 322.17659943, 105.27709946, 352.77439636,
#        250.28779831, 103.68649887, 287.13960083, 155.07280029,
#         94.87679993, 147.71500168, 253.80009628, 155.37910172,
#        106.25360199, 323.8845993 , 295.47620392, 337.025802  ,
#        101.54400032, 357.17400299])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy(R_Squared):',train_accuracy)
test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy(R_squared):',test_accuracy)
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# train_accuracy(R_Squared): 0.9998571271849735
# test_accuracy(R_squared): 0.9987098858585105
# Mean Absolute Error: 1.3038307748950013
# Mean Squared Error: 3.3155240230458447
# Root Mean Squared Error: 1.8208580458250567

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (186, 7)
# (62, 7)
# (186,)
# (62,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(hidden_layer_sizes=(128,64,32),activation='relu',solver='lbfgs')
mlp.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(128, 64, 32), solver='lbfgs')

# %%
y_pred = mlp.predict(x_test)
y_pred
# Out:
# array([159.40376364, 155.21921873, 320.02891652, 259.83005847,
#        329.39236526, 105.58505384,  92.80878125, 286.7699535 ,
#        150.15349637, 104.76672769, 108.923278  , 105.65957545,
#        106.13954595, 325.78412696, 272.60065582, 328.11675316,
#         97.05922635, 147.23473325, 323.20465642, 151.58305014,
#        306.07160469, 152.23185171, 288.87474843, 271.44352657,
#        101.06702578, 103.48820317,  90.48335207, 149.26231134,
#        160.68264651, 273.64090465, 104.76940955, 109.38924387,
#        301.36583077, 151.44166393, 107.32537573, 156.30470219,
#        344.40419119,  89.86959313, 168.05489584, 164.6107618 ,
#        324.88767705, 288.86409588, 165.97433716, 323.63169495,
#        146.77415162, 307.3897362 , 268.65423768, 330.69044985,
#        166.38233614, 333.60741125, 317.73979231, 100.05042566,
#        307.7776838 ,  91.75976494, 106.28990043, 253.39334657,
#        295.16886314,  97.56432077, 280.76144119, 297.18249746,
#        250.23239904, 251.28269821])

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, y_pred)
print("R-squared Score:", r2_score)
# Out:
# R-squared Score: 0.9995922669782261

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 1.378727575550205
# Mean Squared Error: 3.326035308208686
# Root Mean Squared Error: 1.8237421166954186
