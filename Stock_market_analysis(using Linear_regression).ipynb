# %%
import pandas as pd
df=pd.read_csv("D:\\miniproject\\stocks.csv")
df
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# 3    151.009995  57450700
# 4    153.850006  62199000
# ..          ...       ...
# 243  107.709999  20926300
# 244  105.980003  20343100
# 245  106.120003  17116300
# 246  105.209999  19780600
# 247  106.214996  20705300
#
# [248 rows x 8 columns]

# %%
df.head()
# Out:
#   Ticker        Date        Open        High         Low       Close  \
# 0   AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1   AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2   AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3   AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4   AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
#
#     Adj Close    Volume
# 0  154.414230  83322600
# 1  151.688400  64120100
# 2  150.639999  56007100
# 3  151.009995  57450700
# 4  153.850006  62199000

# %%
df['Date']=pd.to_datetime(df.Date)
df['Date']
# Out:
# 0     2023-02-07
# 1     2023-02-08
# 2     2023-02-09
# 3     2023-02-10
# 4     2023-02-13
#          ...
# 243   2023-05-01
# 244   2023-05-02
# 245   2023-05-03
# 246   2023-05-04
# 247   2023-05-05
# Name: Date, Length: 248, dtype: datetime64[ns]

# %%
df.shape
# Out:
# (248, 8)

# %%
df.drop(['Ticker','Adj Close'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close    Volume
# 0 2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1 2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2 2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3 2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4 2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    248 non-null    datetime64[ns]
#  1   Open    248 non-null    float64
#  2   High    248 non-null    float64
#  3   Low     248 non-null    float64
#  4   Close   248 non-null    float64
#  5   Volume  248 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.8 KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  248.000000  248.000000  248.000000  248.000000  2.480000e+02
# mean   215.252093  217.919662  212.697452  215.381674  3.208210e+07
# std     91.691315   92.863023   90.147881   91.461989  2.233590e+07
# min     89.540001   90.129997   88.860001   89.349998  2.657900e+06
# 25%    135.235004  137.440004  134.822495  136.347498  1.714180e+07
# 50%    208.764999  212.614998  208.184998  209.920006  2.734000e+07
# 75%    304.177505  307.565002  295.437500  303.942505  4.771772e+07
# max    372.410004  373.829987  361.739990  366.829987  1.133164e+08

# %%
print('lenghth of dataset:',len(df))
# Out:
# lenghth of dataset: 248

# %%
import matplotlib.pyplot as plt
df['Open'].plot(figsize=(16,6))
plt.title('Linechart')
plt.xlabel('Open')
plt.ylabel('frequency')
plt.show()

# %%
x=df
x['year']=pd.DatetimeIndex(x['Date']).year
x['month']=pd.DatetimeIndex(x['Date']).month
x['day']=pd.DatetimeIndex(x['Date']).day

# %%
x
# Out:
#           Date        Open        High         Low       Close    Volume  \
# 0   2023-02-07  150.639999  155.229996  150.639999  154.649994  83322600
# 1   2023-02-08  153.880005  154.580002  151.169998  151.919998  64120100
# 2   2023-02-09  153.779999  154.330002  150.419998  150.869995  56007100
# 3   2023-02-10  149.460007  151.339996  149.220001  151.009995  57450700
# 4   2023-02-13  150.949997  154.259995  150.919998  153.850006  62199000
# ..         ...         ...         ...         ...         ...       ...
# 243 2023-05-01  107.720001  108.680000  107.500000  107.709999  20926300
# 244 2023-05-02  107.660004  107.730003  104.500000  105.980003  20343100
# 245 2023-05-03  106.220001  108.129997  105.620003  106.120003  17116300
# 246 2023-05-04  106.160004  106.300003  104.699997  105.209999  19780600
# 247 2023-05-05  105.320000  106.440002  104.738998  106.214996  20705300
#
#      year  month  day
# 0    2023      2    7
# 1    2023      2    8
# 2    2023      2    9
# 3    2023      2   10
# 4    2023      2   13
# ..    ...    ...  ...
# 243  2023      5    1
# 244  2023      5    2
# 245  2023      5    3
# 246  2023      5    4
# 247  2023      5    5
#
# [248 rows x 9 columns]

# %%
x=df.drop(['Close','Date'],axis=1)
x
# Out:
#            Open        High         Low    Volume  year  month  day
# 0    150.639999  155.229996  150.639999  83322600  2023      2    7
# 1    153.880005  154.580002  151.169998  64120100  2023      2    8
# 2    153.779999  154.330002  150.419998  56007100  2023      2    9
# 3    149.460007  151.339996  149.220001  57450700  2023      2   10
# 4    150.949997  154.259995  150.919998  62199000  2023      2   13
# ..          ...         ...         ...       ...   ...    ...  ...
# 243  107.720001  108.680000  107.500000  20926300  2023      5    1
# 244  107.660004  107.730003  104.500000  20343100  2023      5    2
# 245  106.220001  108.129997  105.620003  17116300  2023      5    3
# 246  106.160004  106.300003  104.699997  19780600  2023      5    4
# 247  105.320000  106.440002  104.738998  20705300  2023      5    5
#
# [248 rows x 7 columns]

# %%
y=df['Close']
y
# Out:
# 0      154.649994
# 1      151.919998
# 2      150.869995
# 3      151.009995
# 4      153.850006
#           ...
# 243    107.709999
# 244    105.980003
# 245    106.120003
# 246    105.209999
# 247    106.214996
# Name: Close, Length: 248, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (186, 7)
# (62, 7)
# (186,)
# (62,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [-5.45434461e-01  7.34498290e-01  8.12746520e-01  4.09319930e-09
#   6.34908792e-16  1.03687704e-01  1.15818167e-03]

# %%
print(regressor.intercept_)
# Out:
# -0.6115052912800536

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([105.85857405, 333.96873085, 250.74241162, 311.28519689,
#        298.72203511, 252.57616138, 164.91324929, 331.00275856,
#        105.25785819, 102.92673365, 273.32821516,  90.64360737,
#        255.40317671, 331.12356914, 342.36046574,  91.6712785 ,
#        168.06448415, 296.21632029, 105.89362416, 278.38275047,
#         93.67596025, 317.78324839, 346.0692463 , 280.914753  ,
#        160.98083308,  93.78619591, 164.20050281, 287.47227794,
#        270.45727295, 288.53794467, 307.59001879, 151.74176022,
#         95.67940527, 265.26741985, 359.00929825, 152.44792433,
#        148.89679411, 364.91355333, 146.15607972, 319.25252252,
#        107.63243018, 104.87900905, 288.31418623, 329.21735632,
#        250.40020544, 324.40533805, 105.06920989, 359.55324439,
#        249.39064507, 104.18635543, 285.82181447, 155.70870856,
#         94.61028593, 145.83820822, 253.07013501, 155.62258755,
#        106.45123935, 328.76510696, 291.59428566, 338.8283384 ,
#        101.96923654, 365.08969585])

# %%
print(x_test)
# Out:
#            Open        High         Low    Volume  year  month  day
# 247  105.320000  106.440002  104.738998  20705300  2023      5    5
# 168  340.809998  342.799988  330.040009   3965400  2023      4   12
# 76   249.070007  251.490005  248.729996  22491000  2023      2   28
# 150  304.750000  316.600006  301.709991   7903700  2023      3   16
# 145  312.079987  312.510010  294.880005   7443400  2023      3    9
# ..          ...         ...         ...       ...   ...    ...  ...
# 180  325.239990  330.809998  324.000000   4221900  2023      4   28
# 146  297.899994  298.790009  289.000000   5759300  2023      3   10
# 160  340.269989  343.290009  335.299988   7131500  2023      3   30
# 214  101.059998  102.580002  100.790001  26033900  2023      3   20
# 126  372.410004  373.829987  361.739990   6901100  2023      2    9
#
# [62 rows x 7 columns]

# %%
predicted.shape
# Out:
# (62,)

# %%
dframe=pd.DataFrame(y_test,predicted)
dframe
# Out:
#             Close
# 105.858574    NaN
# 333.968731    NaN
# 250.742412    NaN
# 311.285197    NaN
# 298.722035    NaN
# ...           ...
# 328.765107    NaN
# 291.594286    NaN
# 338.828338    NaN
# 101.969237    NaN
# 365.089696    NaN
#
# [62 rows x 1 columns]

# %%
dfr=pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted})
dfr
# Out:
#      Actual Price  Predicted Price
# 247    106.214996       105.858574
# 168    331.029999       333.968731
# 76     249.419998       250.742412
# 150    310.059998       311.285197
# 145    297.779999       298.722035
# ..            ...              ...
# 180    329.929993       328.765107
# 146    292.760010       291.594286
# 160    338.429993       338.828338
# 214    101.930000       101.969237
# 126    362.500000       365.089696
#
# [62 rows x 2 columns]

# %%
dfr.head(60)
# Out:
#      Actual Price  Predicted Price
# 247    106.214996       105.858574
# 168    331.029999       333.968731
# 76     249.419998       250.742412
# 150    310.059998       311.285197
# 145    297.779999       298.722035
# 73     254.770004       252.576161
# 45     165.559998       164.913249
# 159    332.029999       331.002759
# 218    106.059998       105.257858
# 213    102.459999       102.926734
# 96     275.230011       273.328215
# 201     90.510002        90.643607
# 83     252.320007       255.403177
# 176    329.019989       331.123569
# 161    345.480011       342.360466
# 202     92.309998        91.671279
# 55     168.410004       168.064484
# 116    295.369995       296.216320
# 229    106.120003       105.893624
# 92     272.290009       278.382750
# 203     94.019997        93.675960
# 135    323.649994       317.783248
# 162    348.279999       346.069246
# 89     279.429993       280.914753
# 44     160.100006       160.980833
# 207     92.660004        93.786196
# 37     164.899994       164.200503
# 111    288.450012       287.472278
# 63     266.730011       270.457273
# 109    288.799988       288.537945
# 118    307.260010       307.590019
# 8      152.550003       151.741760
# 189     94.860001        95.679405
# 64     263.619995       265.267420
# 129    359.959991       359.009298
# 5      153.199997       152.447924
# 22     148.500000       148.896794
# 125    366.829987       364.913553
# 12     146.710007       146.156080
# 173    323.119995       319.252523
# 241    108.370003       107.632430
# 226    104.949997       104.879009
# 107    289.839996       288.314186
# 156    328.390015       329.217356
# 75     250.160004       250.400205
# 178    321.149994       324.405338
# 235    105.019997       105.069210
# 130    361.420013       359.553244
# 74     249.220001       249.390645
# 224    104.910004       104.186355
# 108    286.140015       285.821814
# 18     153.830002       155.708709
# 205     94.169998        94.610286
# 15     145.309998       145.838208
# 71     252.669998       253.070135
# 7      153.710007       155.622588
# 228    106.949997       106.451239
# 180    329.929993       328.765107
# 146    292.760010       291.594286
# 160    338.429993       338.828338

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy:',train_accuracy)
test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy:',test_accuracy)
# Out:
# train_accuracy: 0.9996274457101879
# test_accuracy: 0.9996351890659423

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean Absolute Error: 1.3038307748950013
# Mean Squared Error: 3.3155240230458447
# Root Mean Squared Error: 1.8208580458250567

# %%
graph=dfr.head(20)
graph
# Out:
#      Actual Price  Predicted Price
# 247    106.214996       105.858574
# 168    331.029999       333.968731
# 76     249.419998       250.742412
# 150    310.059998       311.285197
# 145    297.779999       298.722035
# 73     254.770004       252.576161
# 45     165.559998       164.913249
# 159    332.029999       331.002759
# 218    106.059998       105.257858
# 213    102.459999       102.926734
# 96     275.230011       273.328215
# 201     90.510002        90.643607
# 83     252.320007       255.403177
# 176    329.019989       331.123569
# 161    345.480011       342.360466
# 202     92.309998        91.671279
# 55     168.410004       168.064484
# 116    295.369995       296.216320
# 229    106.120003       105.893624
# 92     272.290009       278.382750

# %%
graph.plot(kind='bar')
plt.title('BarGraph')
plt.xlabel('Actual&prediceted price')
plt.ylabel('frequency')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.90,random_state=100)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24, 7)
# (224, 7)
# (24,)
# (224,)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([269.19530273, 162.61849579, 111.73599777, 288.32009827,
#        121.4580986 , 322.65909546, 313.60870331, 325.48829468,
#        120.2755983 , 320.23179993, 296.97450211, 157.50959747,
#        317.04220078, 321.6759967 , 111.06609787, 316.43419769,
#        270.30110474, 262.53419861, 265.20869858, 121.4580986 ,
#        161.79029938, 111.62249748, 268.68960648, 279.63280396,
#        111.54189751, 111.72609772, 153.67479874, 322.49309509,
#        120.0169986 , 111.73599777, 270.88570679, 321.89189636,
#        151.42619987, 111.05939804, 157.441698  , 282.62859695,
#        314.91120102, 289.74639847, 117.10159798, 161.82139801,
#        307.59650192, 112.75779755, 118.98099831, 112.82779724,
#        266.72889984, 325.29949493, 151.83559967, 287.50319809,
#        264.97230331, 155.3739975 , 159.13649742, 112.6240976 ,
#        321.89189636, 310.4489035 , 161.32529953, 283.88169769,
#        151.63119949, 307.718302  , 161.02289932, 150.70899971,
#        162.9871991 , 325.21969543, 321.51569656, 121.4580986 ,
#        151.21630127, 150.00910065, 113.92159782, 152.87199799,
#        322.88729462, 308.42320206, 111.34609787, 159.70629868,
#        265.90139938, 276.89020447, 313.71040344, 296.5667012 ,
#        266.63619995, 113.00979774, 112.70619774, 113.01829796,
#        111.77649788, 153.50459976, 321.51569656, 154.47719818,
#        298.10540146, 112.73889755, 160.26189911, 311.26480286,
#        312.04630371, 111.77649788, 151.57820038, 112.99419762,
#        264.85419846, 321.4664975 , 326.4866922 , 323.26929871,
#        312.10860306, 112.95109749, 273.99850739, 321.9828006 ,
#        112.94839752, 321.6759967 , 326.35189392, 288.03179916,
#        162.76939911, 288.19649857, 266.4501001 , 112.94279778,
#        162.71559601, 157.69779808, 325.75119507, 112.99419762,
#        111.77649788, 321.6759967 , 111.88999756, 324.5115976 ,
#        112.99419762, 111.02899796, 150.38900208, 152.14409897,
#        308.82460175, 275.3131073 , 112.6559977 , 112.99419762,
#        112.73689774, 266.27879868, 112.99419762, 150.49340195,
#        149.69830078, 157.49169739, 278.07340317, 161.27369858,
#        111.88559769, 112.54229774, 112.70619774, 119.35099846,
#        160.95670105, 111.96689735, 162.11999756, 284.73050079,
#        307.59650192, 293.02799973, 152.49780075, 151.10779938,
#        151.77460114, 161.22989975, 325.13909637, 323.00709442,
#        286.62149734, 112.71969772, 157.49169739, 266.86809906,
#        307.59650192, 285.11159637, 282.09500198, 265.81679962,
#        112.1165976 , 320.76559937, 266.58350037, 152.34240097,
#        159.57469879, 160.19639778, 112.70619774, 322.49309509,
#        121.13049843, 112.6559977 , 266.93320129, 322.75439606,
#        325.97939484, 323.68039886, 151.58499924, 264.85419846,
#        113.01909782, 272.02580612, 112.36229774, 112.66079735,
#        157.56219757, 286.62819809, 152.11460144, 266.72889984,
#        150.53109955, 112.65519783, 322.49309509, 153.48799759,
#        319.13439331, 160.45269867, 288.03179916, 322.49309509,
#        162.82539963, 121.25309845, 324.17669739, 287.11409729,
#        161.96769791, 155.21039749, 322.42669586, 268.70930603,
#        293.30539993, 285.88309738, 307.59650192, 151.15600021,
#        266.1221994 , 112.99379768, 318.05879913, 112.6240976 ,
#        162.48869583, 121.4580986 , 324.53199768, 162.05409882,
#        324.85959625, 111.59489761, 119.14049828, 272.86180847,
#        152.50100021, 287.09089737, 121.51109833, 312.09450211,
#        321.25479736, 324.99479584, 325.19749451, 288.19649857,
#        313.90640076, 321.42079773, 265.07980133, 277.99090515])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy:',train_accuracy)
R_test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy:',R_test_accuracy)
# Out:
# train_accuracy: 0.9983936096505511
# test_accuracy: 0.9811984384340094

# %%
import matplotlib.pyplot as plt
linear_regression_accuracy =0.9995657233927607
random_forest_accuracy =0.9863406841303611
accuracy_scores = [linear_regression_accuracy, random_forest_accuracy]
model_names = ['Linear Regression', 'Random Forest Regression']
plt.bar(model_names, accuracy_scores)
plt.xlabel('Regression Models')
plt.ylabel('Test Accuracy')
plt.title('Comparison of Test Accuracy: Linear Regression vs Random Forest Regression')
plt.show()
